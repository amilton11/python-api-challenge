# %% [markdown]
# # WeatherPy
# ----
#
# #### Observable trends
# 1. There is little to no correlation between latitude & cloudiness, latitude & wind speed and latitude & humidity.
# 2. There is a strong correlation between latitude & temperature.
# 3. City density goes down the further away you get from the equator.
# 4. Wind speed is below <10 mph for most cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
import requests
import time
from scipy.stats import linregress
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# Import API keys
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# set up list to hold response info
city_name = []
country = []
lat = []
lon = []
date = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []

# Loop through the list of cities and perform a request for the weather data on each city
for city in cities:
# city = cities[601]

#print(f"Getting data for {city} on {date}")   

    response = requests.get(query_url + city).json()

    try:
        city_name.append(response['name'])

        country.append(response['sys']['country'])

        lat.append(response['coord']['lat'])

        lon.append(response['coord']['lon'])

        date.append(response['dt'])

        max_temp.append(response['main']['temp_max'])

        humidity.append(response['main']['humidity'])

        cloudiness.append(response['clouds']['all'])

        wind_speed.append(response['wind']['speed'])

        print(f"Getting data for {city}") 


    except KeyError: 
        print(f"Record does not exist for {city}")
# Out:
# Getting data for bluff
# Getting data for qixingtai
# Getting data for cape town
# Getting data for kahului
# Getting data for pevek
# Record does not exist for nizhneyansk
# Getting data for vaini
# Getting data for okhotsk
# Getting data for hanzhong
# Getting data for rockport
# Getting data for faanui
# Getting data for necochea
# Getting data for kaitangata
# Getting data for carnarvon
# Getting data for businga
# Getting data for maple creek
# Getting data for biltine
# Getting data for heiligenhafen
# Getting data for ushuaia
# Getting data for atuona
# Getting data for griffith
# Getting data for sangar
# Getting data for rikitea
# Getting data for port macquarie
# Getting data for albany
# Getting data for balkhash
# Getting data for saint-philippe
# Record does not exist for ruatoria
# Getting data for namibe
# Getting data for villahermosa
# Getting data for norman wells
# Getting data for maldonado
# Getting data for punta arenas
# Getting data for qaanaaq
# Record does not exist for taolanaro
# Getting data for longyearbyen
# Getting data for bequimao
# Getting data for tres picos
# Getting data for hami
# Getting data for senta
# Getting data for torbay
# Record does not exist for sentyabrskiy
# Getting data for jamestown
# Getting data for berlevag
# Getting data for bredasdorp
# Getting data for esperance
# Getting data for avarua
# Record does not exist for mys shmidta
# Getting data for hobyo
# Getting data for lata
# Getting data for ribeira grande
# Getting data for summerside
# Getting data for quelimane
# Getting data for zmeinogorsk
# Record does not exist for barawe
# Getting data for qaqortoq
# Record does not exist for illoqqortoormiut
# Getting data for henties bay
# Getting data for sawtell
# Getting data for yellowknife
# Getting data for vila franca do campo
# Getting data for imeni poliny osipenko
# Getting data for port alfred
# Getting data for ilulissat
# Getting data for gamba
# Getting data for coruripe
# Getting data for birao
# Getting data for alugan
# Getting data for avera
# Getting data for butaritari
# Getting data for hithadhoo
# Getting data for teguldet
# Getting data for puerto leguizamo
# Record does not exist for belushya guba
# Getting data for itarema
# Getting data for tefe
# Getting data for halifax
# Getting data for severo-kurilsk
# Getting data for saskylakh
# Getting data for sao filipe
# Getting data for castro
# Getting data for mataura
# Getting data for antsohihy
# Getting data for kibala
# Getting data for barrow
# Getting data for narsaq
# Record does not exist for grand river south east
# Getting data for east london
# Getting data for hermanus
# Getting data for monywa
# Getting data for nieves
# Getting data for rio grande
# Getting data for busselton
# Record does not exist for meyungs
# Getting data for port keats
# Getting data for lagoa
# Getting data for luderitz
# Getting data for ishigaki
# Record does not exist for samalaeulu
# Getting data for pachino
# Getting data for port elizabeth
# Getting data for fuzhou
# Getting data for touros
# Getting data for sibolga
# Getting data for lebu
# Record does not exist for umzimvubu
# Getting data for cidreira
# Getting data for luunja
# Getting data for moerai
# Getting data for changping
# Getting data for maceio
# Getting data for iqaluit
# Getting data for hilo
# Record does not exist for attawapiskat
# Getting data for cabo san lucas
# Getting data for mount isa
# Getting data for san mateo del mar
# Getting data for san jose
# Getting data for thompson
# Getting data for calama
# Getting data for lorengau
# Getting data for port lincoln
# Getting data for stornoway
# Getting data for puerto ayora
# Getting data for jubbal
# Getting data for mar del plata
# Getting data for nelson bay
# Getting data for mahebourg
# Getting data for bambous virieux
# Record does not exist for eskasem
# Getting data for funadhoo
# Record does not exist for barentsburg
# Getting data for dudhani
# Getting data for wakema
# Getting data for xuddur
# Getting data for kapaa
# Getting data for naze
# Getting data for bac lieu
# Getting data for puerto madero
# Getting data for coihaique
# Getting data for kasempa
# Getting data for bengkulu
# Getting data for jiuquan
# Getting data for kruisfontein
# Getting data for vardo
# Getting data for fortuna
# Getting data for huanren
# Getting data for kundiawa
# Getting data for yakeshi
# Getting data for vao
# Getting data for brae
# Getting data for arroyo
# Getting data for idenao
# Getting data for ketchikan
# Getting data for nalut
# Getting data for tuktoyaktuk
# Getting data for new norfolk
# Getting data for san bonifacio
# Getting data for chadiza
# Getting data for kununurra
# Getting data for bandarbeyla
# Getting data for chokurdakh
# Getting data for hambantota
# Getting data for awbari
# Getting data for azangaro
# Getting data for taoudenni
# Getting data for solnechnyy
# Getting data for srednekolymsk
# Getting data for bayan
# Getting data for gazanjyk
# Getting data for dera bugti
# Getting data for codrington
# Getting data for tiksi
# Getting data for aklavik
# Getting data for christchurch
# Getting data for billings
# Getting data for yeppoon
# Getting data for katsuura
# Record does not exist for bolshaya irba
# Getting data for vanavara
# Getting data for bulaevo
# Getting data for pisco
# Getting data for mahajanga
# Getting data for mariahu
# Getting data for prudy
# Getting data for guangyuan
# Getting data for kemin
# Getting data for hasaki
# Getting data for teguise
# Record does not exist for sedelnikovo
# Getting data for moron
# Getting data for bathsheba
# Getting data for airai
# Getting data for georgetown
# Getting data for matai
# Getting data for khatanga
# Getting data for upernavik
# Getting data for manta
# Getting data for jonkoping
# Getting data for nikolskoye
# Getting data for sakakah
# Getting data for rodrigues alves
# Getting data for gravelbourg
# Getting data for hobart
# Getting data for quatre cocos
# Getting data for tucuman
# Getting data for comodoro rivadavia
# Getting data for ginda
# Getting data for isangel
# Getting data for senneterre
# Getting data for husavik
# Getting data for borogontsy
# Getting data for mecca
# Getting data for taldan
# Getting data for banda aceh
# Getting data for gigmoto
# Getting data for makasar
# Getting data for vallenar
# Getting data for sao joao da barra
# Getting data for riyadh
# Getting data for olafsvik
# Getting data for san cristobal
# Getting data for coahuayana
# Getting data for morrope
# Getting data for naifaru
# Getting data for flinders
# Getting data for liverpool
# Getting data for cambridge
# Getting data for vila velha
# Getting data for sorland
# Getting data for vredendal
# Getting data for kalakamati
# Getting data for bay roberts
# Getting data for kodiak
# Getting data for vung tau
# Getting data for laem sing
# Getting data for lake city
# Getting data for rio verde de mato grosso
# Getting data for erenhot
# Getting data for maraba
# Getting data for oranjemund
# Getting data for vieux-habitants
# Getting data for tasiilaq
# Getting data for dekalb
# Getting data for aksu
# Getting data for broome
# Getting data for sorsk
# Getting data for bukama
# Getting data for beringovskiy
# Record does not exist for tumannyy
# Getting data for beniganj
# Getting data for chuy
# Getting data for cherskiy
# Getting data for laguna
# Record does not exist for satitoa
# Getting data for saldanha
# Getting data for derzhavinsk
# Getting data for nhulunbuy
# Record does not exist for amderma
# Getting data for kavaratti
# Getting data for cumbal
# Getting data for palmer
# Getting data for skibbereen
# Getting data for katete
# Getting data for tulun
# Getting data for waipawa
# Getting data for victoria
# Getting data for belaya gora
# Getting data for elat
# Getting data for narrabri
# Getting data for acapulco
# Getting data for fort nelson
# Getting data for santa cruz
# Getting data for mehamn
# Getting data for kaiyuan
# Getting data for chara
# Getting data for yala
# Getting data for saint-georges
# Getting data for quime
# Getting data for whitianga
# Getting data for hay river
# Getting data for sobolevo
# Getting data for clonakilty
# Getting data for villa bruzual
# Getting data for te anau
# Getting data for alice springs
# Getting data for nome
# Getting data for port-gentil
# Getting data for chanika
# Record does not exist for uwayl
# Getting data for yerbogachen
# Record does not exist for louisbourg
# Getting data for svarstad
# Getting data for natal
# Getting data for cabrera
# Getting data for kaeo
# Getting data for safaga
# Getting data for morehead
# Getting data for hirara
# Getting data for san quintin
# Getting data for gazli
# Getting data for storm lake
# Getting data for arraial do cabo
# Getting data for alekseyevskaya
# Getting data for kungurtug
# Getting data for areka
# Getting data for monastyrshchina
# Getting data for chiredzi
# Getting data for zatoka
# Getting data for burnie
# Getting data for chinsali
# Getting data for lavrentiya
# Getting data for inuvik
# Getting data for manggar
# Getting data for dingle
# Getting data for maringa
# Getting data for kandrian
# Getting data for novi pazar
# Getting data for porto nacional
# Getting data for bafra
# Getting data for alta floresta
# Getting data for san lawrenz
# Getting data for sukumo
# Getting data for jacala
# Getting data for rawson
# Getting data for puerto cabezas
# Getting data for cacapava do sul
# Getting data for sao gabriel da cachoeira
# Getting data for severnyy-kospashskiy
# Getting data for calbuco
# Getting data for coquimbo
# Getting data for lujan
# Getting data for tuatapere
# Getting data for felsoszentivan
# Getting data for padang
# Getting data for lagos de moreno
# Getting data for myitkyina
# Getting data for izumo
# Getting data for iranshahr
# Getting data for sokoto
# Getting data for saint-augustin
# Getting data for nanortalik
# Getting data for muli
# Getting data for nha trang
# Getting data for matay
# Getting data for mumbwa
# Getting data for dao
# Getting data for poum
# Getting data for kazanskaya
# Getting data for hailey
# Getting data for hailin
# Getting data for sioux lookout
# Getting data for krusevac
# Getting data for la ronge
# Getting data for shimoda
# Getting data for paamiut
# Getting data for gravdal
# Getting data for shizunai
# Getting data for aranos
# Record does not exist for bokspits
# Getting data for dikson
# Getting data for alpena
# Getting data for ponta do sol
# Record does not exist for palabuhanratu
# Getting data for santa marta
# Getting data for meulaboh
# Getting data for saint simons
# Getting data for ambunti
# Getting data for destin
# Getting data for buraydah
# Getting data for yungay
# Getting data for tyup
# Getting data for tubuala
# Getting data for nuuk
# Getting data for guerrero negro
# Getting data for huangchuan
# Getting data for westport
# Getting data for sambava
# Getting data for bulungu
# Getting data for terpinnya
# Getting data for geraldton
# Getting data for tignere
# Getting data for uribia
# Getting data for moindou
# Getting data for sretensk
# Getting data for hofn
# Getting data for matagami
# Getting data for raduzhnyy
# Getting data for grindavik
# Getting data for las matas de farfan
# Getting data for turuvekere
# Getting data for dourbali
# Getting data for tevriz
# Getting data for ajuchitlan
# Getting data for terrace
# Getting data for sainte-martine
# Getting data for klaksvik
# Getting data for bestobe
# Getting data for ilo
# Getting data for shingu
# Getting data for takoradi
# Getting data for balkanabat
# Record does not exist for dibaya
# Getting data for clyde river
# Getting data for kjollefjord
# Getting data for odessa
# Record does not exist for urdzhar
# Getting data for leningradskiy
# Getting data for egvekinot
# Getting data for bethel
# Getting data for rocha
# Getting data for la tuque
# Getting data for pozo colorado
# Getting data for tual
# Record does not exist for mutsamudu
# Getting data for khor
# Getting data for homer
# Getting data for gornoye loo
# Getting data for yar-sale
# Getting data for worland
# Getting data for caravelas
# Getting data for chichimila
# Getting data for jamsa
# Getting data for batagay
# Getting data for wakkanai
# Getting data for beloha
# Getting data for praia
# Getting data for watertown
# Getting data for ilinge
# Getting data for ngunguru
# Getting data for evensk
# Getting data for tshikapa
# Getting data for lentini
# Getting data for beira
# Getting data for atar
# Getting data for kavieng
# Getting data for canico
# Getting data for mezhdurechensk
# Getting data for timmins
# Getting data for provideniya
# Getting data for prince rupert
# Getting data for vidim
# Getting data for youghal
# Getting data for saucillo
# Getting data for luanda
# Getting data for kralendijk
# Getting data for porto novo
# Getting data for monaghan
# Getting data for krasnoselkup
# Getting data for revelstoke
# Getting data for haibara
# Getting data for port blair
# Getting data for rumonge
# Record does not exist for alotau
# Getting data for sokoni
# Getting data for kasongo-lunda
# Getting data for sungaipenuh
# Getting data for vicuna
# Getting data for tomari
# Getting data for beidao
# Getting data for sola
# Getting data for taiping
# Getting data for port hardy
# Getting data for davie
# Getting data for aneho
# Getting data for balancan
# Getting data for ancud
# Getting data for cockburn town
# Getting data for karaton
# Getting data for iquique
# Getting data for tura
# Getting data for puerto colombia
# Getting data for gat
# Getting data for preobrazheniye
# Getting data for ben tre
# Getting data for west wendover
# Getting data for marzuq
# Getting data for gumdag
# Getting data for minab
# Getting data for faya
# Getting data for saquena
# Getting data for fairbanks
# Getting data for owak
# Getting data for svetlaya
# Getting data for saint-pierre
# Getting data for kuala terengganu
# Getting data for tabou
# Getting data for tongliao
# Getting data for souillac
# Getting data for lyuban
# Getting data for eldorado
# Getting data for lakatoro
# Record does not exist for toftir
# Getting data for pasni
# Record does not exist for rungata
# Getting data for senj
# Getting data for ozernovskiy
# Getting data for botwood
# Getting data for hanyang
# Getting data for dordrecht
# Getting data for zhicheng
# Getting data for talnakh
# Getting data for lapua
# Getting data for yulara
# Getting data for kichmengskiy gorodok
# Getting data for kumluca
# Getting data for juneau
# Getting data for katangli
# Getting data for hovd
# Getting data for marolambo
# Getting data for sisimiut
# Getting data for seneffe
# Getting data for mala
# Getting data for eureka
# Getting data for constitucion
# Getting data for amalapuram
# Getting data for bakchar
# Getting data for rakkestad
# Getting data for port hedland
# Getting data for parabel
# Getting data for turukhansk
# Getting data for pangnirtung
# Getting data for venado tuerto
# Record does not exist for kuche
# Getting data for naantali
# Getting data for raudeberg
# Getting data for khandyga
# Getting data for havre-saint-pierre
# Getting data for oktyabrskoye
# Getting data for neuquen
# Getting data for nioro
# Getting data for boa vista
# Getting data for wisconsin rapids
# Getting data for salalah
# Getting data for dalbandin
# Getting data for idil
# Getting data for kokopo
# Getting data for pacific grove
# Getting data for kidal
# Getting data for jiazi
# Getting data for moroni
# Getting data for pulgaon
# Getting data for kuliyapitiya
# Getting data for whitehorse
# Record does not exist for burkhala
# Getting data for hamilton
# Getting data for dudinka
# Getting data for estepona
# Getting data for cortez
# Getting data for imatra
# Getting data for biak
# Getting data for marawi
# Getting data for mahibadhoo
# Getting data for mayo
# Getting data for uaua
# Getting data for pringsewu
# Getting data for chumikan
# Getting data for salinopolis
# Getting data for rafai
# Getting data for sabratah
# Getting data for port moresby
# Getting data for north bend
# Getting data for portland
# Getting data for huazhou
# Record does not exist for tagabas
# Getting data for mineiros
# Getting data for noumea
# Getting data for thinadhoo
# Getting data for flin flon
# Getting data for natitingou
# Getting data for san rafael
# Getting data for tra vinh
# Getting data for puerto madryn
# Getting data for assiniboia
# Getting data for rogatica
# Getting data for chukhloma
# Record does not exist for ondorhaan
# Getting data for americus
# Getting data for maragheh
# Getting data for temixco
# Getting data for marion
# Getting data for richards bay
# Getting data for chapais
# Record does not exist for vaitupu
# Getting data for caborca
# Getting data for isparta
# Getting data for udachnyy
# Record does not exist for katsiveli
# Getting data for ayacucho
# Getting data for slupsk
# Getting data for cayenne
# Getting data for buchanan
# Getting data for gasa
# Getting data for montepuez
# Getting data for bella vista
# Getting data for papetoai
# Getting data for price
# Getting data for berezovyy
# Getting data for dunedin
# Getting data for malatya
# Getting data for oristano
# Getting data for esso
# Getting data for vestmanna
# Getting data for ambilobe
# Getting data for novy bydzov
# Getting data for maraa
# Getting data for vostok
# Getting data for honiara
# Getting data for fallon
# Record does not exist for rawannawi
# Record does not exist for tabiauea
# Getting data for gaozhou

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert raw data into a data frame
weather_dict = {"City": city_name, "Country": country, "Lat": lat, "Lon": lon, "Date": date, "Max Temp (cs)": max_temp, "Humidity": humidity, 
                        "Cloudiness": cloudiness, "Wind Speed (mph)": wind_speed}


weather_df = pd.DataFrame(weather_dict)
# Display the DataFrame
weather_df
# Out:
#           City Country      Lat       Lon        Date  Max Temp (cs)  \
# 0        Bluff      NZ -46.6000  168.3333  1611878714           8.89
# 1    Qixingtai      CN  30.4135  111.8874  1611878840           4.54
# 2    Cape Town      ZA -33.9258   18.4232  1611878172          17.22
# 3      Kahului      US  20.8947 -156.4700  1611878840          27.00
# 4        Pevek      RU  69.7008  170.3133  1611878841         -29.58
# ..         ...     ...      ...       ...         ...            ...
# 569      Maraã      BR  -1.8333  -65.3667  1611878928          24.07
# 570     Vostok      RU  46.4856  135.8833  1611878928         -21.47
# 571    Honiara      SB  -9.4333  159.9500  1611878929          26.92
# 572     Fallon      US  39.4735 -118.7774  1611878929           9.00
# 573    Gaozhou      CN  21.9392  110.8461  1611878929          14.91
#
#      Humidity  Cloudiness  Wind Speed (mph)
# 0          80         100              3.58
# 1          69           0              1.53
# 2          82           0              2.06
# 3          54          40             11.32
# 4          87          49              0.77
# ..        ...         ...               ...
# 569        95          82              0.82
# 570        91         100              1.89
# 571        83         100              4.32
# 572        49          90              9.26
# 573        59          29              1.36
#
# [574 rows x 9 columns]

# %%
# Export the city data into a .csv using encoding utf-8 to avoid issues later
weather_df.to_csv("weather_data.csv", encoding="utf-8", index=False)

# index=False, header=True

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
#Find the max humidity
print(weather_df["Humidity"].max())
print(weather_df["Humidity"].min())
print("\n" f"There are no cities with humidity >100% within this dataset.")
print("\n" f"Humidity that is >100% is called supersaturation. At any given temperature and air pressure, a specific maximum amount of water vapor in the air will produce a relative humidity (RH) of 100 percent. Supersaturated air literally contains more water vapor than is needed to cause saturation.")
# Out:
# 100
# 16
#
# There are no cities with humidity >100% within this dataset.
#
# Humidity that is >100% is called supersaturation. At any given temperature and air pressure, a specific maximum amount of water vapor in the air will produce a relative humidity (RH) of 100 percent. Supersaturated air literally contains more water vapor than is needed to cause saturation.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = weather_df['Max Temp (cs)']
y_values = weather_df['Lat']
plt.scatter(x_values,y_values, marker='.', s = weather_df['Max Temp (cs)']*1, c=weather_df['Max Temp (cs)'], cmap='viridis')
# plt.colorbar()
plt.title('City Latitude vs Temperature 1/27/21')
plt.xlabel('Temperature (cs)')
plt.ylabel('Latitude')
plt.grid(color='teal', linestyle='-', linewidth=.15) 

# Save the plot as a png
plt.savefig("lat_vs_temp_plot.png")
plt.show()

# Add a sentence or two explaining what the code is analyzing.
print(f'The code is analysing the relationship between city latitude and temperature.')
print(f'The closer a city is to the equator (0 latitude) the warmer the temperature.')
# Out:
# /Users/abigailmilton/opt/anaconda3/lib/python3.8/site-packages/matplotlib/collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# The code is analysing the relationship between city latitude and temperature.
# The closer a city is to the equator (0 latitude) the warmer the temperature.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = weather_df['Humidity']
y_values = weather_df['Lat']
plt.scatter(x_values,y_values, marker='.', s = weather_df['Humidity']*1, c=weather_df['Humidity'], cmap='viridis')
# plt.colorbar()
plt.title('City Latitude vs Humidity 1/27/21')
plt.xlabel('Humidity')
plt.ylabel('Latitude')
plt.grid(color='teal', linestyle='-', linewidth=.15)

# Save the plot as a png
plt.savefig("lat_vs_hum_plot.png")
plt.show()

# Add a sentence or two explaining what the code is analyzing.
print(f'The code is analysing the relationship between city latitude and humidity.')
print(f'There is no obvious relationship between latitude and humidity.')
# Out:
# The code is analysing the relationship between city latitude and humidity.
# There is no obvious relationship between latitude and humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = weather_df['Cloudiness']
y_values = weather_df['Lat']
plt.scatter(x_values,y_values, marker='.', s = weather_df['Cloudiness']*1, c=weather_df['Cloudiness'], cmap='viridis')
# plt.colorbar()
plt.title('City Latitude vs Cloudiness 1/27/21')
plt.xlabel('Cloudiness')
plt.ylabel('Latitude')
plt.grid(color='teal', linestyle='-', linewidth=.15)

# Save the plot as a png
plt.savefig("lat_vs_cloud_plot.png")
plt.show()

# Add a sentence or two explaining what the code is analyzing.
print(f'The code is analysing the relationship between city latitude and cloudiness.')
print(f'There is no obvious relationship between latitude and cloudiness.')
# Out:
# The code is analysing the relationship between city latitude and cloudiness.
# There is no obvious relationship between latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = weather_df['Wind Speed (mph)']
y_values = weather_df['Lat']
plt.scatter(x_values,y_values, marker='.', s = weather_df['Wind Speed (mph)']*1, c=weather_df['Wind Speed (mph)'], cmap='viridis')
# plt.colorbar()
plt.title('City Latitude vs Wind Speed 1/27/21')
plt.xlabel('Wind Speed (mph)')
plt.ylabel('Latitude')
plt.grid(color='teal', linestyle='-', linewidth=.15)

# Save the plot as a png
plt.savefig("lat_vs_wind_plot.png")
plt.show()

# Add a sentence or two explaining what the code is analyzing.
print(f'The code is analysing the relationship between city latitude and wind speed.')
print(f'While there is no obvious relationship between latitude and wind speed, most cities have wind speeds of <10 mph.')
# Out:
# The code is analysing the relationship between city latitude and wind speed.
# While there is no obvious relationship between latitude and wind speed, most cities have wind speeds of <10 mph.

# %% [markdown]
# ## Linear Regression

# %%
#Create a N. Hemisphere and S. Hemosphere weather_df
mask = weather_df['Lat'] > 0
nor_hem_weather = weather_df[mask]
sou_hem_weather = weather_df[~mask]

# %%
sou_hem_weather
# Out:
#           City Country      Lat       Lon        Date  Max Temp (cs)  \
# 0        Bluff      NZ -46.6000  168.3333  1611878714           8.89
# 2    Cape Town      ZA -33.9258   18.4232  1611878172          17.22
# 5        Vaini      TO -21.2000 -175.2000  1611878841          26.00
# 9       Faanui      PF -16.4833 -151.7500  1611878594          27.31
# 10    Necochea      AR -38.5473  -58.7368  1611878841          18.33
# ..         ...     ...      ...       ...         ...            ...
# 559   Papetoai      PF -17.4961 -149.8729  1611878792          29.00
# 562    Dunedin      NZ -45.8742  170.5036  1611878927          11.67
# 567   Ambilobe      MG -13.2000   49.0500  1611878928          23.29
# 569      Maraã      BR  -1.8333  -65.3667  1611878928          24.07
# 571    Honiara      SB  -9.4333  159.9500  1611878929          26.92
#
#      Humidity  Cloudiness  Wind Speed (mph)
# 0          80         100              3.58
# 2          82           0              2.06
# 5          94          75              9.77
# 9          67         100              2.77
# 10         70         100              4.11
# ..        ...         ...               ...
# 559        74          40              1.03
# 562        69          91             11.18
# 567        92          81              1.04
# 569        95          82              0.82
# 571        83         100              4.32
#
# [183 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = nor_hem_weather['Max Temp (cs)']
y = nor_hem_weather['Lat']

# Calculate the correlation coefficient
correlation = st.pearsonr(x, y)
print(f"The correlation between City Latitude and Temperature in the N. Hemisphere is {round(correlation[0],2)}.\n The correlation is negative and strong.")

# Linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Creat the scatter plot w/ lineaer regression
plt.scatter(x, y, marker='.', s = nor_hem_weather['Max Temp (cs)']*1, c=nor_hem_weather['Max Temp (cs)'], cmap='viridis')
plt.plot(x,regress_values,"r-")

# Annotate the linear regression
plt.annotate(line_eq,(-50,0),fontsize=12,color="tomato")

# # Set limits on x and y axis
# plt.xlim(-1, 35)
# plt.ylim(-30, 80)

# Add labels
plt.title('City Latitude vs Temperature (N. Hemisphere) 1/27/21')
plt.xlabel('Temperature (cs)')
plt.ylabel('Latitude')

# Save the plot as a png
plt.savefig("nh_latvstemp_lr_plot.png")
plt.show()

# Add a sentence or two explaining what the code is analyzing.
print(f'The code is analysing the relationship between city latitude and temperature in the northern hemisphere.')
print(f'The closer a city is to the equator (0 latitude) the warmer the temperature.')
# Out:
# The correlation between City Latitude and Temperature in the N. Hemisphere is -0.85.
#  The correlation is negative and strong.
# /Users/abigailmilton/opt/anaconda3/lib/python3.8/site-packages/matplotlib/collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# /Users/abigailmilton/opt/anaconda3/lib/python3.8/site-packages/matplotlib/collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# The code is analysing the relationship between city latitude and temperature in the northern hemisphere.
# The closer a city is to the equator (0 latitude) the warmer the temperature.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = sou_hem_weather['Max Temp (cs)']
y = sou_hem_weather['Lat']

# Calculate the correlation coefficient
correlation = st.pearsonr(x, y)
print(f"The correlation between City Latitude and Temperature in the S. Hemisphere is {round(correlation[0],2)}.\n The correlation is positive and moderate.")

# Linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Creat the scatter plot w/ lineaer regression
plt.scatter(x, y, marker='.', s = sou_hem_weather['Max Temp (cs)']*1, c=sou_hem_weather['Max Temp (cs)'], cmap='viridis')
plt.plot(x,regress_values,"r-")

# Annotate the linear regression
plt.annotate(line_eq,(23,-55),fontsize=12,color="tomato")

# # Set limits on x and y axis
# plt.xlim(-1, 35)
# plt.ylim(-30, 80)

# Add labels
plt.title('City Latitude vs Temperature (S. Hemisphere) 1/27/21')
plt.xlabel('Temperature (cs)')
plt.ylabel('Latitude')

# Save plot as png
plt.savefig("sh_latvstemp_lr_plot.png")
plt.show()

# Add a sentence or two explaining what the code is analyzing.
print(f'The code is analysing the relationship between city latitude and temperature in the southern hemisphere.')
print(f'The closer a city is to the equator (0 latitude) the warmer the temperature.')
print(f'City density goes down the further away you get from the equator.')
# Out:
# The correlation between City Latitude and Temperature in the S. Hemisphere is 0.56.
#  The correlation is positive and moderate.
# The code is analysing the relationship between city latitude and temperature in the southern hemisphere.
# The closer a city is to the equator (0 latitude) the warmer the temperature.
# City density goes down the further away you get from the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = nor_hem_weather['Humidity']
y = nor_hem_weather['Lat']

# Calculate the correlation coefficient
correlation = st.pearsonr(x, y)
print(f"The correlation between City Latitude and Humidity in the N. Hemisphere is {round(correlation[0],2)}. \n The correlation is positive and weak.")

# Linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Creat the scatter plot w/ lineaer regression
plt.scatter(x, y, marker='.', s = nor_hem_weather['Humidity']*1, c=nor_hem_weather['Humidity'], cmap='viridis')
plt.plot(x,regress_values,"r-")

# Annotate the linear regression
plt.annotate(line_eq,(15,75),fontsize=12,color="tomato")

# # Set limits on x and y axis
# plt.xlim(-1, 35)
# plt.ylim(-30, 80)

# Add labels
plt.title('City Latitude vs Humidity (N. Hemisphere) 1/27/21')
plt.xlabel('Humidity')
plt.ylabel('Latitude')

# Save plot as png
plt.savefig("nh_latvshumid_lr_plot.png")
plt.show()

# Add a sentence or two explaining what the code is analyzing.
print(f'The code is analysing the relationship between city latitude and humidty in the northern hemisphere.')
print(f'Latitude is not showing an impact on humidity.')
# Out:
# The correlation between City Latitude and Humidity in the N. Hemisphere is 0.32.
#  The correlation is positive and weak.
# The code is analysing the relationship between city latitude and humidty in the northern hemisphere.
# Latitude is not showing an impact on humidity.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = sou_hem_weather['Humidity']
y = sou_hem_weather['Lat']

# Calculate the correlation coefficient
correlation = st.pearsonr(x, y)
print(f"The correlation between City Latitude and Humidity in the S. Hemisphere is {round(correlation[0],2)}.\n The correlation is positive and weak.")

# Linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Creat the scatter plot w/ lineaer regression
plt.scatter(x, y, marker='.', s = sou_hem_weather['Humidity']*1, c=sou_hem_weather['Humidity'], cmap='viridis')
plt.plot(x,regress_values,"r-")

# Annotate the linear regression
plt.annotate(line_eq,(20,-55),fontsize=12,color="tomato")

# # Set limits on x and y axis
# plt.xlim(-1, 35)
# plt.ylim(-30, 80)

# Add labels
plt.title('City Latitude vs Humidity (S. Hemisphere) 1/27/21')
plt.xlabel('Humidity')
plt.ylabel('Latitude')

# Save plot as png
plt.savefig("sh_latvshumid_lr_plot.png")
plt.show()

# Add a sentence or two explaining what the code is analyzing.
print(f'The code is analysing the relationship between city latitude and humidty in the southern hemisphere.')
print(f'Latitude is not showing an impact on humidity.')
# Out:
# The correlation between City Latitude and Humidity in the S. Hemisphere is 0.32.
#  The correlation is positive and weak.
# The code is analysing the relationship between city latitude and humidty in the southern hemisphere.
# Latitude is not showing an impact on humidity.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = nor_hem_weather['Cloudiness']
y = nor_hem_weather['Lat']

# Calculate the correlation coefficient
correlation = st.pearsonr(x, y)
print(f"The correlation between City Latitude and Cloudiness in the N. Hemisphere is {round(correlation[0],2)}.\n The correlation is positive and very weak.")

# Linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Creat the scatter plot w/ lineaer regression
plt.scatter(x, y, marker='.', s = nor_hem_weather['Cloudiness']*1, c=nor_hem_weather['Cloudiness'], cmap='GnBu')
plt.plot(x,regress_values,"r-")

# Annotate the linear regression
plt.annotate(line_eq,(0,0),fontsize=12,color="tomato")

# # Set limits on x and y axis
# plt.xlim(-1, 35)
# plt.ylim(-30, 80)

# Add labels
plt.title('City Latitude vs Cloudiness (N. Hemisphere) 1/27/21')
plt.xlabel('Cloudiness')
plt.ylabel('Latitude')

# Save plot as png
plt.savefig("nh_latvscloud_lr_plot.png")
plt.show()

# Add a sentence or two explaining what the code is analyzing.
print(f'The code is analysing the relationship between city latitude and cloudiness in the northern hemisphere.')
print(f'Latitude is not showing an impact on cloudiness.')
# Out:
# The correlation between City Latitude and Cloudiness in the N. Hemisphere is 0.19.
#  The correlation is positive and very weak.
# The code is analysing the relationship between city latitude and cloudiness in the northern hemisphere.
# Latitude is not showing an impact on cloudiness.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = sou_hem_weather['Cloudiness']
y = sou_hem_weather['Lat']

# Calculate the correlation coefficient
correlation = st.pearsonr(x, y)
print(f"The correlation between City Latitude and Cloudiness in the S. Hemisphere is {round(correlation[0],2)}.\n The correlation is positive and very weak.")

# Linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Creat the scatter plot w/ lineaer regression
plt.scatter(x, y, marker='.', s = sou_hem_weather['Cloudiness']*1, c=sou_hem_weather['Cloudiness'], cmap='GnBu')
plt.plot(x,regress_values,"r-")

# Annotate the linear regression
plt.annotate(line_eq,(0,-55),fontsize=12,color="tomato")

# # Set limits on x and y axis
# plt.xlim(-1, 35)
# plt.ylim(-30, 80)

# Add labels
plt.title('City Latitude vs Cloudiness (S. Hemisphere) 1/27/21')
plt.xlabel('Cloudiness')
plt.ylabel('Latitude')

# Save plot as png
plt.savefig("sh_latvscloud_lr_plot.png")
plt.show()

# Add a sentence or two explaining what the code is analyzing.
print(f'The code is analysing the relationship between city latitude and cloudiness in the southern hemisphere.')
print(f'Latitude is not showing an impact on cloudiness.')
# Out:
# The correlation between City Latitude and Cloudiness in the S. Hemisphere is 0.19.
#  The correlation is positive and very weak.
# The code is analysing the relationship between city latitude and cloudiness in the southern hemisphere.
# Latitude is not showing an impact on cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = nor_hem_weather['Wind Speed (mph)']
y = nor_hem_weather['Lat']

# Calculate the correlation coefficient
correlation = st.pearsonr(x, y)
print(f"The correlation between City Latitude and Wind Speed in the N. Hemisphere is {round(correlation[0],2)}.\n The correlation is slightly negative and almost non-existant.")

# Linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Creat the scatter plot w/ lineaer regression
plt.scatter(x, y, marker='^', s = nor_hem_weather['Wind Speed (mph)']*3, c=nor_hem_weather['Wind Speed (mph)'], cmap='cool')
plt.plot(x,regress_values,"r-")

# Annotate the linear regression
plt.annotate(line_eq,(12,0),fontsize=12,color="tomato")

# # Set limits on x and y axis
# plt.xlim(-1, 35)
# plt.ylim(-30, 80)

# Add labels
plt.title('City Latitude vs Wind Speed (N. Hemisphere) 1/27/21')
plt.xlabel('Wind Speed')
plt.ylabel('Latitude')

# Save plot as png
plt.savefig("nh_latvswind_lr_plot.png")
plt.show()

# Add a sentence or two explaining what the code is analyzing.
print(f'The code is analysing the relationship between city latitude and wind speed in the northern hemisphere.')
print(f'Latitude is not showing an impact on windpseed.')
# Out:
# The correlation between City Latitude and Wind Speed in the N. Hemisphere is -0.01.
#  The correlation is slightly negative and almost non-existant.
# The code is analysing the relationship between city latitude and wind speed in the northern hemisphere.
# Latitude is not showing an impact on windpseed.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = sou_hem_weather['Wind Speed (mph)']
y = sou_hem_weather['Lat']

# Calculate the correlation coefficient
correlation = st.pearsonr(x, y)
print(f"The correlation between City Latitude and Wind Speed in the S. Hemisphere is {round(correlation[0],2)}. \n The correlation is negative and very weak.")

# Linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Creat the scatter plot w/ lineaer regression
plt.scatter(x, y, marker='^', s = sou_hem_weather['Wind Speed (mph)']*3, c=sou_hem_weather['Wind Speed (mph)'], cmap='cool')
plt.plot(x,regress_values,"r-")

# Annotate the linear regression
plt.annotate(line_eq,(0,-55),fontsize=12,color="tomato")

# # Set limits on x and y axis
# plt.xlim(-1, 35)
# plt.ylim(-30, 80)

# Add labels
plt.title('City Latitude vs Wind Speed (S. Hemisphere) 1/27/21')
plt.xlabel('Wind Speed')
plt.ylabel('Latitude')

# Save plot as png
plt.savefig("sh_latvswind_lr_plot.png")
plt.show()

# Add a sentence or two explaining what the code is analyzing.
print(f'The code is analysing the relationship between city latitude and wind speed in the southern hemisphere.')
print(f'Latitude is not showing an impact on windpseed.')
# Out:
# The correlation between City Latitude and Wind Speed in the S. Hemisphere is -0.25.
#  The correlation is negative and very weak.
# The code is analysing the relationship between city latitude and wind speed in the southern hemisphere.
# Latitude is not showing an impact on windpseed.
