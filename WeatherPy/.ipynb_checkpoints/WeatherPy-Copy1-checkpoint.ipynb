# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API keys
from api_keys import weather_api_key
from api_keys import g_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %%
cities
# Out:
# ['celestun',
#  'vaini',
#  'cape town',
#  'mar del plata',
#  'ushuaia',
#  'albany',
#  'punta arenas',
#  'rikitea',
#  'qaanaaq',
#  'grand gaube',
#  'mataura',
#  'avarua',
#  'belushya guba',
#  'port macquarie',
#  'saint george',
#  'gladstone',
#  'bontang',
#  'belyy yar',
#  'cherskiy',
#  'unai',
#  'hilo',
#  'namatanai',
#  'campos altos',
#  'bredasdorp',
#  'manitouwadge',
#  'sentyabrskiy',
#  'baturaja',
#  'kapaa',
#  'nanakuli',
#  'kolyvan',
#  'georgetown',
#  'yellowknife',
#  'skelleftea',
#  'ulverstone',
#  'kavieng',
#  'hermanus',
#  'sibu',
#  'nouadhibou',
#  'jamestown',
#  'coihaique',
#  'nanortalik',
#  'ribeira grande',
#  'port alfred',
#  'severo-kurilsk',
#  'glenwood springs',
#  'chalmette',
#  'tuktoyaktuk',
#  'mullaitivu',
#  'pevek',
#  'aksha',
#  'bursol',
#  'katsuura',
#  'husavik',
#  'jiuquan',
#  'hobart',
#  'ossora',
#  'mayor pablo lagerenza',
#  'dryden',
#  'severomuysk',
#  'saldanha',
#  'east london',
#  'mount gambier',
#  'wahiawa',
#  'sangin',
#  'attawapiskat',
#  'bluff',
#  'kanpur',
#  'klaksvik',
#  'butaritari',
#  'illoqqortoormiut',
#  'houston',
#  'kloulklubed',
#  'barrow',
#  'huarmey',
#  'sosnovka',
#  'busselton',
#  'palabuhanratu',
#  'ambikapur',
#  'llata',
#  'loikaw',
#  'mahebourg',
#  'saint-philippe',
#  'beringovskiy',
#  'hithadhoo',
#  'luderitz',
#  'koslan',
#  'san cristobal',
#  'chenghai',
#  'saskylakh',
#  'jadu',
#  'takab',
#  'tasiilaq',
#  'bethel',
#  'aitape',
#  'broome',
#  'barentsburg',
#  'gat',
#  'teneguiban',
#  'kavaratti',
#  'deer lake',
#  'lilongwe',
#  'meiganga',
#  'am timan',
#  'ancud',
#  'torbay',
#  'deputatskiy',
#  'debre tabor',
#  'livenka',
#  'teya',
#  'guerrero negro',
#  'upernavik',
#  'khatanga',
#  'jinchang',
#  'kenai',
#  'vao',
#  'saleaula',
#  'port elizabeth',
#  'suntar',
#  'magadan',
#  'rungata',
#  'hasaki',
#  'gorodets',
#  'jizan',
#  'san pedro',
#  'srednekolymsk',
#  'bolungarvik',
#  'linxia',
#  'new norfolk',
#  'fort william',
#  'felipe carrillo puerto',
#  'dezhou',
#  'clyde river',
#  'havre-saint-pierre',
#  'thompson',
#  'kharan',
#  'sretensk',
#  'rzhaksa',
#  'verkhnyaya maksakovka',
#  'ratnagiri',
#  'santa vitoria do palmar',
#  'cabo san lucas',
#  'pangai',
#  'lagoa',
#  'vila franca do campo',
#  'kazanskaya',
#  'ye',
#  'dwarka',
#  'nokaneng',
#  'polewali',
#  'arraial do cabo',
#  'bud',
#  'aflu',
#  'kuldur',
#  'vila velha',
#  'norman wells',
#  'higuey',
#  'chokurdakh',
#  'tsihombe',
#  'vestmanna',
#  'lebu',
#  'labuhan',
#  'pisco',
#  'juifang',
#  'faanui',
#  'parczew',
#  'kupang',
#  'namibe',
#  'shebunino',
#  'rio largo',
#  'shubarshi',
#  'sorong',
#  'avera',
#  'nizhneyansk',
#  'ponta delgada',
#  'xichang',
#  'atuona',
#  'itaituba',
#  'valparaiso',
#  'jambi',
#  'vila',
#  'kruisfontein',
#  'krasnoselkup',
#  'pathein',
#  'ballina',
#  'powell river',
#  'kamaishi',
#  'poso',
#  'tuatapere',
#  'caravelas',
#  'cumaribo',
#  'milkovo',
#  'necochea',
#  'chicama',
#  'castro',
#  'taolanaro',
#  'ghanzi',
#  'grand river south east',
#  'lagos',
#  'sorland',
#  'solano',
#  'hegang',
#  'dzhebariki-khaya',
#  'amderma',
#  'chebsara',
#  'poum',
#  'beloha',
#  'narsaq',
#  'saint-francois',
#  'leningradskiy',
#  'atasu',
#  'ilulissat',
#  'puerto ayora',
#  'maues',
#  'russell',
#  'henties bay',
#  'chantada',
#  'tzucacab',
#  'majene',
#  'anshun',
#  'tonantins',
#  'yulara',
#  'coahuayana',
#  'slave lake',
#  'saint-joseph',
#  'kushima',
#  'chuy',
#  'haines junction',
#  'bambous virieux',
#  'messina',
#  'kuytun',
#  'adrasmon',
#  'along',
#  'kingaroy',
#  'tiksi',
#  'fortuna',
#  'beyneu',
#  'amarpur',
#  'labytnangi',
#  'trujillo',
#  'baneh',
#  'pangnirtung',
#  'constitucion',
#  'westport',
#  'henderson',
#  'jacareacanga',
#  'berlevag',
#  'markdale',
#  'calabaca',
#  'bur gabo',
#  'mercedes',
#  'port hedland',
#  'bonthe',
#  'umzimvubu',
#  'puerto escondido',
#  'adrar',
#  'north platte',
#  'dunedin',
#  'waipawa',
#  'buckingham',
#  'hualmay',
#  'longyearbyen',
#  'gorontalo',
#  'sakaiminato',
#  'nikolskoye',
#  'yamada',
#  'marzuq',
#  'shimoda',
#  'newcastle',
#  'mapiripan',
#  'kingman',
#  'vanavara',
#  'kaitangata',
#  'sitka',
#  'shenjiamen',
#  'bengkulu',
#  'ambilobe',
#  'east haddam',
#  'san ramon',
#  'damoh',
#  'antalaha',
#  'jamkhandi',
#  'velyka lepetykha',
#  'meulaboh',
#  'lebedyn',
#  'manama',
#  'oudtshoorn',
#  'cockburn town',
#  'tres arroyos',
#  'vila do maio',
#  'buala',
#  'port moresby',
#  'roebourne',
#  'landazuri',
#  'salta',
#  'scottsbluff',
#  'teguldet',
#  'carnarvon',
#  'chikoy',
#  'iracoubo',
#  'codrington',
#  'roald',
#  'hami',
#  'annau',
#  'lafiagi',
#  'puerto leguizamo',
#  'jasper',
#  'borodino',
#  'vardo',
#  'cabedelo',
#  'nome',
#  'halvad',
#  'springbok',
#  'victoria',
#  'kahului',
#  'agadir',
#  'mahibadhoo',
#  'mount isa',
#  'manzanillo',
#  'port blair',
#  'cervo',
#  'palmer',
#  'kibre mengist',
#  'banda aceh',
#  'ponta do sol',
#  'tabuk',
#  'ngunguru',
#  'bairiki',
#  'sao joao da barra',
#  'saint-pierre',
#  'carutapera',
#  'chiredzi',
#  'quatre cocos',
#  'nalut',
#  'vanimo',
#  'talcahuano',
#  'yakeshi',
#  'kamuli',
#  'pathalgaon',
#  'arlit',
#  'bloemfontein',
#  'bull savanna',
#  'pemangkat',
#  'grindavik',
#  'raga',
#  'naze',
#  'aksarka',
#  'sao filipe',
#  'anqing',
#  'diego de almagro',
#  'kurud',
#  'ariquemes',
#  'dikson',
#  'katherine',
#  'kaka',
#  'marcona',
#  'mahonda',
#  'aklavik',
#  'mirnyy',
#  'maneadero',
#  'fort nelson',
#  'lluta',
#  'santa cruz',
#  'salinas',
#  'grants',
#  'ulaangom',
#  'gazli',
#  'erenhot',
#  'teknaf',
#  'hofn',
#  'el paso',
#  'batsfjord',
#  'provideniya',
#  'kamsack',
#  'birjand',
#  'spokane',
#  'cilegon',
#  'dudinka',
#  'kodiak',
#  'nago',
#  'concepcion',
#  'esmeraldas',
#  'gayny',
#  'dunmore town',
#  'boone',
#  'mys shmidta',
#  'killybegs',
#  'kota bahru',
#  'taoudenni',
#  'stoyba',
#  'semirom',
#  'anadyr',
#  'shingu',
#  'kieta',
#  'esperance',
#  'sao jose da coroa grande',
#  'rawson',
#  'harta',
#  'touros',
#  'rurrenabaque',
#  'terny',
#  'somerset east',
#  'lagunas',
#  'wanning',
#  'shubarkuduk',
#  'sedelnikovo',
#  'srandakan',
#  'nyimba',
#  'cidreira',
#  'seoul',
#  'ahipara',
#  'goroka',
#  'maniitsoq',
#  'kortkeros',
#  'talnakh',
#  'panagjuriste',
#  'kuala krai',
#  'gilgit',
#  'kulhudhuffushi',
#  'half moon bay',
#  'lavrentiya',
#  'ruteng',
#  'acapulco',
#  'jilib',
#  'naftah',
#  'aripuana',
#  'kerouane',
#  'sur',
#  'geraldton',
#  'egersund',
#  'shahreza',
#  'raudeberg',
#  'nemuro',
#  'kautokeino',
#  'kuche',
#  'middelburg',
#  'washington',
#  'amga',
#  'play cu',
#  'goderich',
#  'rabo de peixe',
#  'faya',
#  'nizhniy odes',
#  'chara',
#  'rincon',
#  'isangel',
#  'conneaut',
#  'warmbad',
#  'feijo',
#  'kununurra',
#  'clovis',
#  'khani',
#  'tara',
#  'liverpool',
#  'kawalu',
#  'awjilah',
#  'alugan',
#  'omboue',
#  'yirol',
#  'tacoronte',
#  'rorvik',
#  'souillac',
#  'ferkessedougou',
#  'mabaruma',
#  'sikonge',
#  'maiduguri',
#  'lakhdenpokhya',
#  'gorno-chuyskiy',
#  'souris',
#  'ngaoundere',
#  'loandjili',
#  'kommunar',
#  'mohiuddinagar',
#  'shihezi',
#  'benjamin constant',
#  'yenagoa',
#  'dali',
#  'kutum',
#  'kurumkan',
#  'thinadhoo',
#  'flinders',
#  'tabiauea',
#  'samusu',
#  'mwinilunga',
#  'north bend',
#  'outlook',
#  'redmond',
#  'iskateley',
#  'cimislia',
#  'safwah',
#  'halifax',
#  'tabialan',
#  'sahuaripa',
#  'diffa',
#  'senanga',
#  'jiran',
#  'mookane',
#  'karasburg',
#  'honiara',
#  'egvekinot',
#  'eyemouth',
#  'grand-santi',
#  'niamey',
#  'muros',
#  'tilichiki',
#  'samarai',
#  'yining',
#  'san juan',
#  'cartagena',
#  'methven',
#  'vereeniging',
#  'inhambane',
#  'muhos',
#  'coronel bogado',
#  'bathsheba',
#  'tateyama',
#  'churapcha',
#  'torata',
#  'ust-kamchatsk',
#  'sambava',
#  'moron',
#  'afrikanda',
#  'puerto penasco',
#  'wana',
#  'chupa',
#  'bilibino',
#  'aruja',
#  'chagda',
#  'lingao',
#  'ouesso',
#  'kandrian',
#  'serov',
#  'makakilo city',
#  'andilamena',
#  'san francisco',
#  'winnemucca',
#  'komsomolskiy',
#  'los llanos de aridane',
#  'kurilsk',
#  'palmeiras de goias',
#  'estelle',
#  'jiaonan',
#  'sisimiut',
#  'champasak',
#  'moranbah',
#  'doha',
#  'college',
#  'olafsvik',
#  'vaitupu',
#  'bouna',
#  'camacupa',
#  'whitehorse',
#  'dafeng',
#  'mergui',
#  'bara',
#  'tayturka',
#  'salalah',
#  'sylva',
#  'kilindoni',
#  'san javier',
#  'stuttgart',
#  'kauhajoki',
#  'petropavlovsk-kamchatskiy',
#  'hue',
#  'sechura',
#  'ngukurr',
#  'armacao dos buzios',
#  'sol-iletsk',
#  'mezen',
#  'high level',
#  'nuevo progreso',
#  'glendive',
#  'aquiraz',
#  'road town',
#  'rehoboth',
#  'saint paul',
#  'kapit',
#  'brigantine',
#  'zaria',
#  'madoc',
#  'kainantu',
#  'lompoc',
#  'mlimba',
#  'madang',
#  'pozo colorado',
#  'scarborough',
#  'ust-nera',
#  'khrebtovaya',
#  'tyup',
#  'la ronge',
#  'kargil',
#  'bereda',
#  'tamiahua',
#  'kidal',
#  'haverfordwest',
#  'puerto narino',
#  'palmerston',
#  'felidhoo',
#  'khulo',
#  'inuvik',
#  'luganville',
#  'saint-augustin',
#  'bonavista',
#  'isla mujeres',
#  'nha trang',
#  'portland',
#  'khasan',
#  'comodoro rivadavia',
#  'siocon',
#  'cap malheureux',
#  'karratha',
#  'mombetsu',
#  'weligama',
#  'aras',
#  'oyama',
#  'pachino',
#  'maningrida',
#  'kontagora',
#  'tura',
#  'ikryanoye',
#  'edd',
#  'itarema',
#  'svetlogorsk',
#  'mackay',
#  'rundu',
#  'mandalgovi']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# set up list to hold response info
city_name = []
country = []
lat = []
lon = []
date = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []

# Loop through the list of cities and perform a request for the weather data on each city
for city in cities:
# city = cities[601]

#print(f"Getting data for {city} on {date}")   

    response = requests.get(query_url + city).json()

    try:
        city_name.append(response['name'])

        country.append(response['sys']['country'])

        lat.append(response['coord']['lat'])

        lon.append(response['coord']['lon'])

        date.append(response['dt'])

        max_temp.append(response['main']['temp_max'])

        humidity.append(response['main']['humidity'])

        cloudiness.append(response['clouds']['all'])

        wind_speed.append(response['wind']['speed'])

        print(f"Getting data for {city}") 


    except KeyError: 
        print("Record does not exist")
# Out:
# Getting data for celestun
# Getting data for petropavlovsk-kamchatskiy
# Getting data for hue
# Getting data for sechura
# Record does not exist
# Record does not exist
# Getting data for sol-iletsk
# Getting data for mezen
# Getting data for high level
# Getting data for nuevo progreso
# Getting data for glendive
# Getting data for aquiraz
# Getting data for road town
# Getting data for rehoboth
# Getting data for saint paul
# Getting data for kapit
# Getting data for brigantine
# Getting data for zaria
# Getting data for madoc
# Getting data for kainantu
# Getting data for lompoc
# Getting data for mlimba
# Getting data for madang
# Getting data for pozo colorado
# Getting data for scarborough
# Getting data for ust-nera
# Getting data for khrebtovaya
# Getting data for tyup
# Getting data for la ronge
# Getting data for kargil
# Getting data for bereda
# Getting data for tamiahua
# Getting data for kidal
# Getting data for haverfordwest
# Getting data for puerto narino
# Getting data for palmerston
# Record does not exist
# Getting data for khulo
# Getting data for inuvik
# Getting data for luganville
# Getting data for saint-augustin
# Getting data for bonavista
# Getting data for isla mujeres
# Getting data for nha trang
# Getting data for portland
# Getting data for khasan
# Getting data for comodoro rivadavia
# Getting data for siocon
# Getting data for cap malheureux
# Getting data for karratha
# Getting data for mombetsu
# Getting data for weligama
# Getting data for aras
# Getting data for oyama
# Getting data for pachino
# Getting data for maningrida
# Getting data for kontagora
# Getting data for tura
# Getting data for ikryanoye
# Getting data for edd
# Getting data for itarema
# Getting data for svetlogorsk
# Getting data for mackay
# Getting data for rundu
# Getting data for mandalgovi

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert raw data into a data frame
weather_dict = {"City": city_name, "Country": country, "Lat": lat, "Lon": lon, "Date": date, "Max Temp": max_temp, "Humidity": humidity, 
                        "Cloudiness": cloudiness, "Wind Speed": wind_speed}


weather_df = pd.DataFrame(weather_dict)
# Display the DataFrame
weather_df
# Out:
#               City Country      Lat       Lon        Date  Max Temp  Humidity  \
# 0         Celestún      MX  20.8667  -90.4000  1611695250     29.40        60
# 1            Vaini      TO -21.2000 -175.2000  1611694987     26.00        89
# 2        Cape Town      ZA -33.9258   18.4232  1611694720     20.00        77
# 3    Mar del Plata      AR -38.0023  -57.5575  1611694978     23.89        88
# 4          Ushuaia      AR -54.8000  -68.3000  1611695056      6.00        70
# ..             ...     ...      ...       ...         ...       ...       ...
# 572        Itarema      BR  -2.9248  -39.9167  1611695320     27.18        77
# 573   Forsytheganj      BY  52.6333   29.7333  1611695320     -0.22        98
# 574         Mackay      AU -21.1500  149.2000  1611694967     25.00        94
# 575          Rundu      NA -17.9333   19.7667  1611695321     20.51        90
# 576     Mandalgovi      MN  45.7625  106.2708  1611694747    -20.30        77
#
#      Cloudiness  Wind Speed
# 0             0        1.03
# 1            75        3.09
# 2            20        8.75
# 3             0        3.09
# 4            90       12.86
# ..          ...         ...
# 572         100        6.56
# 573         100       10.64
# 574          75        2.06
# 575         100        0.41
# 576         100        3.93
#
# [577 rows x 9 columns]

# %%
# Export the city data into a .csv using encoding utf-8 to avoid issues later
weather_df.to_csv("weather_data.csv", encoding="utf-8", index=False)

# index=False, header=True

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
#Find the max humidity
print(weather_df["Humidity"].max())
print(weather_df["Humidity"].min())
# Out:
# 100
# 9

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
